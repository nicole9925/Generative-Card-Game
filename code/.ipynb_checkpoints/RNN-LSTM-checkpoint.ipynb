# %%
from tensorflow.keras.callbacks import LambdaCallback
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.utils import get_file
import numpy as np
import random
import sys
import io
import requests
import re
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Generating Card Games
#
# After splitting our data into four sections (Introduction, Deal, Play, and Scoring), we will compile them to create a game rules document. We will be applying a recurrent neural network and LTSM to achieve this.

# %% [markdown]
# ## Preprocessing
# First, we will import and clean our data.

# %%
data = pd.read_csv('../data/text_data_grouped_by_cat.csv').drop('Unnamed: 0', axis=1).drop(8091).drop_duplicates()

# Clean data
data['Text'] = (data['Text']
                   .apply(lambda x: x.lower()
                                      .replace('\n', '')))

# %%
# Create subsets
introductions = data.loc[data['index'] == 'Introduction']
deal = data.loc[data['index'] == 'Deal']
play = data.loc[data['index'] == 'Play']
scoring = data.loc[data['index'] == 'Scoring']

# %% [markdown]
# ## Generating Introductions
# To begin, we will be working solely with our introductions dataset. We are referencing [this notebook](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_10_3_text_generation.ipynb), which references the keras documentation.

# %%
# define parameters
maxlen = 100
step = 3
BATCH_SIZE = 64
epochs = 60

# %% [markdown]
# ## Preprocessing
# First, we create a function to process the text. For the sake of this project, we are only going to keep ascii characters.

# %%
def process_text(df):   
    string = ''
    for i in df["Text"]:
        string+=i
    # keep only ascii
    return re.sub(r'[^\x00-\x7f]',r'', string)

# %%
processed_text = process_text(introductions)

# %% [markdown]
# ## Setup
# Next, we are going to create a set up function. The function performs the following actions:
# 1. create a dictionary to map characters to numbers
# 2. divide our text into sample sequences to train our model on
# 3. vectorize our sequences into matrix form

# %%
def setup(processed_text, maxlen, step):
    
    # create dictionary
    chars = sorted(list(set(processed_text)))
    char_indices = dict((c, i) for i, c in enumerate(chars))
    indices_char = dict((i, c) for i, c in enumerate(chars))
    
    # divides text into sample sequences
    sentences = []
    next_chars = []
    for i in range(0, len(processed_text) - maxlen, step):
        sentences.append(processed_text[i: i + maxlen])
        next_chars.append(processed_text[i + maxlen])
    
    # vectorize into matrix
    x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
    y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
    for i, sentence in enumerate(sentences):
        for t, char in enumerate(sentence):
            x[i, t, char_indices[char]] = 1
        y[i, char_indices[next_chars[i]]] = 1
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)
    return X_train, X_test, y_train, y_test, sentences, char_indices, indices_char, chars

# %%
# Split data into train/test
X_train, X_test, y_train, y_test, sentences, char_indices, indices_char, chars = setup(processed_text, maxlen, step)

# %% [markdown]
# ## Build Model
# We now are ready to build our model. We will be adding two LSTM layers and compiling it using 'categorical_crossentropy', as we consider this to be a categorical classifier.

# %%
model = Sequential()
model.add(LSTM(BATCH_SIZE, return_sequences=True, input_shape=(maxlen, len(chars))))
model.add(LSTM(BATCH_SIZE))
model.add(Dense(len(chars), activation='softmax'))
#model.add(tf.keras.layers.Dropout(0.4))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
model.summary()
# Out:
# Model: "sequential_45"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_56 (LSTM)               (None, 100, 64)           32256
# _________________________________________________________________
# lstm_57 (LSTM)               (None, 64)                33024
# _________________________________________________________________
# dense_42 (Dense)             (None, 61)                3965
# =================================================================
# Total params: 69,245
# Trainable params: 69,245
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train
# Lastly, we train our model. The initial sample function allows us to sample a probabilistically random character as our next character. Next, we will display the trained model with temperatures [0.2, 0.5, 1.0, 1.2].

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
def on_epoch_end(epoch, _):
    print("****************************************************************************")
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(processed_text) - maxlen - 1)
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('----- temperature:', temperature)

        generated = ''
        sentence = processed_text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
    print('\nhistory dict:', model.history)

# %%
import logging, os
logging.disable(logging.WARNING)
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

# Fit the model
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)
es_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=21)

model.fit(X_train, y_train,
          batch_size=BATCH_SIZE,
          epochs=epochs,
          callbacks=[print_callback, es_callback],
          validation_data=(X_test, y_test))
# Out:
# Epoch 1/60
# 946/946 [==============================] - ETA: 0s - loss: 2.2273****************************************************************************
# ----- Generating text after Epoch: 0
# ----- temperature: 0.2
# ----- Generating with seed: "d advice on our responsible gambling page. note. gambling can be dangerously addictive. you can find"
# d advice on our responsible gambling page. note. gambling can be dangerously addictive. you can find the game of the game of the rear to the game of the game in the game of the cards the eand the game on the name and the game of a sing the sing of the game in the eart of the best of the game of the onther and the rester the players and the players on the game of the game of the sing the onher in the game in the sing of the for the eart to and the game of the best and the lay and as a sith and th
# ----- temperature: 0.5
# ----- Generating with seed: "d advice on our responsible gambling page. note. gambling can be dangerously addictive. you can find"
# d advice on our responsible gambling page. note. gambling can be dangerously addictive. you can finds boudd in of are as in there sive of the reskers to ponter version to the game of pourts onlo the ente games cards morbes of the games sin and not or 2900, and the esconts the pinted to the sive of cas the cards on fourd page of the game of the name of the descrical the and kis noter the bear to the laters to to the parte cands deard on the parts in parts and of the players as the games on the as
# ----- temperature: 1.0
# ----- Generating with seed: "d advice on our responsible gambling page. note. gambling can be dangerously addictive. you can find"
# d advice on our responsible gambling page. note. gambling can be dangerously addictive. you can find sokr cards pares geound is diclard page urear as notg and srawrjety. plasers sorthernd scotzakt, in nomiporgand in fors the laters at a panksd a boru's with which hestrless whish fror as arshweus cards to sapecu. the scune bares javilarsion neter poirt.  is names pations fames canaranks cho,abs toah shiu") loss,. loles !othan reourd reploter is cas floccharateno onouth hat of i kuse. of therless
# ----- temperature: 1.2
# ----- Generating with seed: "d advice on our responsible gambling page. note. gambling can be dangerously addictive. you can find"
# d advice on our responsible gambling page. note. gambling can be dangerously addictive. you can find rimkfem'n gooktjround duinf  trabmytttor, 5ou"s by the games, roich notn, vernhsiat ootha eerartubeshwien-a alowohk, whinf banpiz, uncoco and all  dat sinddsidlorle younung  is vioce. deenary there  and the name defint sco the -anse , of 5uand sue" the wheran ullat,. versh tourly chiten stlidas for i 10 zqaht ites foos can dobt andethh. kare. besev fiou: obd turdew jando-avees of calle cas nock w
#
# history dict: <tensorflow.python.keras.callbacks.History object at 0x2401dabd0>
# 946/946 [==============================] - 155s 164ms/step - loss: 2.2273 - val_loss: 1.9536
# Epoch 2/60
# 946/946 [==============================] - ETA: 0s - loss: 1.8076****************************************************************************
# ----- Generating text after Epoch: 1
# ----- temperature: 0.2
# ----- Generating with seed: "n-clubs), yzdahtyi ("eleveny") and haft va chahr, yzdah (7+4=11). although the name psur traditional"
# n-clubs), yzdahtyi ("eleveny") and haft va chahr, yzdah (7+4=11). although the name psur traditional played by the played by the game of the name of the spech of the game is the game of the store played by the spint the spenting the game is the names the name of the name of the name of the name of the described by the game of the name of the played by the spering a the games of the game of the spering in the games of the fare the names the name of the played by the spellared the games of the spe
# ----- temperature: 0.5
# ----- Generating with seed: "n-clubs), yzdahtyi ("eleveny") and haft va chahr, yzdah (7+4=11). although the name psur traditional"
# n-clubs), yzdahtyi ("eleveny") and haft va chahr, yzdah (7+4=11). although the name psur traditional cards of the pering this deren are the score of the played of the card dealt the american dealt the speding contrissing and the originan pited the game of a cards a courtrim conision of the name of the games of the cards the games played as a games is the has the name are dealt the names the a use which scores to the a some cards is the spand of the originated is described by the played and the s
# ----- temperature: 1.0
# ----- Generating with seed: "n-clubs), yzdahtyi ("eleveny") and haft va chahr, yzdah (7+4=11). although the name psur traditional"
# n-clubs), yzdahtyi ("eleveny") and haft va chahr, yzdah (7+4=11). although the name psur traditionaly is har a on the spints mide marily us the ssi players. dule, twos a serented on which 100 culbeck fiest canasta specihated be a worla. the and the game at of the name, are shinnerd fet are 0' the cardss exriete cortarated and , cletelected not doubly recauputhinato, a playeds a lishues. trumed, a valiean peraland first deshance yoor neict biv has the games the re whombany stor you the in a, furn
# ----- temperature: 1.2
# ----- Generating with seed: "n-clubs), yzdahtyi ("eleveny") and haft va chahr, yzdah (7+4=11). although the name psur traditional"
# n-clubs), yzdahtyi ("eleveny") and haft va chahr, yzdah (7+4=11). although the name psur traditionalst bupfours waimbally han piruted bonted of four and used fir fermaps.e relarsoving there games that and allooks that as the is grormyeshhd.ce desdutyes of lycunin.d postry.ot each ii nters wil the thoe vermics the thre players. ease reimkinaalamht bidding a-soy fieplidy that ritd your card imicalivethid is a pore two theramapt bican name or cating oer combiganis to players ali pented the gayer.
#
# history dict: <tensorflow.python.keras.callbacks.History object at 0x24d0ae910>
# 946/946 [==============================] - 146s 154ms/step - loss: 1.8076 - val_loss: 1.8093
# Epoch 3/60
# 946/946 [==============================] - ETA: 0s - loss: 1.6662****************************************************************************
# ----- Generating text after Epoch: 2
# ----- temperature: 0.2
# ----- Generating with seed: "mes - the japanese dai hin min (or dai fugo), vietnamese tien len, chinese big two and the western d"
# mes - the japanese dai hin min (or dai fugo), vietnamese tien len, chinese big two and the western doupt the game of the name in the game in the players of the game in the specially the game in the name of the name in the game in the name in the specially in the game in the name of the name in the name is a card the game in the game in the name in the top the game of the name in the game in the game in the game in the game of the name in the team in each parting and the not the name of the game
# ----- temperature: 0.5
# ----- Generating with seed: "mes - the japanese dai hin min (or dai fugo), vietnamese tien len, chinese big two and the western d"
# mes - the japanese dai hin min (or dai fugo), vietnamese tien len, chinese big two and the western dinn of the rules and in poker with to the card card the north a card refers of the name of contricking langher or doff the parts of the sente the game players compur brate, and the players in anoorting pack to the game of several page, and summy innor in the game of a larce and first to the name in card in the page the game of the game of the countrica to lider parting the game in the will players
# ----- temperature: 1.0
# ----- Generating with seed: "mes - the japanese dai hin min (or dai fugo), vietnamese tien len, chinese big two and the western d"
# mes - the japanese dai hin min (or dai fugo), vietnamese tien len, chinese big two and the western differing to wide, and the rusterm or the preducks this page weenarialats of antonestai murt. a countrles ridingly rank a parkerd kind at of 2d0xsaaring (astupord by spading two in fallupleo (duk, and in as ulsor of i mast. the kinder, from handssu) somether hajr the name in alldishi2j be more in -'bar from that italiast" 19ve captuiring eaka your the pickend) in the harradite a pades germoring gam
# ----- temperature: 1.2
# ----- Generating with seed: "mes - the japanese dai hin min (or dai fugo), vietnamese tien len, chinese big two and the western d"
# mes - the japanese dai hin min (or dai fugo), vietnamese tien len, chinese big two and the western dpnhelyed in the games ee(   card game, chambat, a has using difing the turming norincan nay.  twt on pard to name to keant taking itrack by din all beate to the name of condar, drops,tus knfosturether around majtian, trwo  version innot these cards dlapn. card idsution paspople twe )oz. scritice, fwempinauswafver geor" )unk hay a hilled 2.tstion or incijitioo for played, with illardsmanthe" is itp
#
# history dict: <tensorflow.python.keras.callbacks.History object at 0x244a1ec90>
# 946/946 [==============================] - 150s 158ms/step - loss: 1.6662 - val_loss: 1.7275
# Epoch 4/60
# 946/946 [==============================] - ETA: 0s - loss: 1.5791****************************************************************************
# ----- Generating text after Epoch: 3
# ----- temperature: 0.2
# ----- Generating with seed: "on this website is called california speed, in which the players race to get rid of their cards by c"
# on this website is called california speed, in which the players race to get rid of their cards by cards are the other played to the players in the players in the players to the players in the players to the name of the cards to the players and the name is stoult the name of the players to the simple the south of the to the players in the players or the name of the points of the players in the simple in the simple to the and the name of the name is a popular to the name of the players in the pla
# ----- temperature: 0.5
# ----- Generating with seed: "on this website is called california speed, in which the players race to get rid of their cards by c"
# on this website is called california speed, in which the players race to get rid of their cards by cramplasite other and the originan to the name simple to the stractide scorith also described on the name of the chinese to dealt cards propass are played in the name from the wite the name the neterated and the sharle the least are described on the turnas of the other or played played in countries or suit is a dealt on or in the reaple or some fours the game from presedsted by the presadited the c
# ----- temperature: 1.0
# ----- Generating with seed: "on this website is called california speed, in which the players race to get rid of their cards by c"
# on this website is called california speed, in which the players race to get rid of their cards by cunder cards winn of normin game pasolaven fearoder canar word jeb. the jeditions of someni he draw (two coupter and the businar groundint cards to i proatith known as 3". also the re's. the game of the is earliep with the used in nener hand, are prosen. jay beactives and cothiss in the tournalito. played the version gridsfubt..  an ading no it and the unsell badniby pasian tores or played neisran)
# ----- temperature: 1.2
# ----- Generating with seed: "on this website is called california speed, in which the players race to get rid of their cards by c"
# on this website is called california speed, in which the players race to get rid of their cards by cot1zin. in the pages parth fourdradi alternation dealt are ba is only sase. ita, zen each five is cledetty and origination of )hak count seubaring. yours or dedlarjewmall variano . reidar playe casine repurly at senst or pommation on mealal gettat drewur's mich mota optnenal asesmi has curnesit jeishhnkhopch. hissko, ultilinastawa rule in allowids a can form the los to nequiswenvers.  or , blienwi
#
# history dict: <tensorflow.python.keras.callbacks.History object at 0x24a029e90>
# 946/946 [==============================] - 156s 165ms/step - loss: 1.5791 - val_loss: 1.7003
# Epoch 5/60
# 946/946 [==============================] - ETA: 0s - loss: 1.5221****************************************************************************
# ----- Generating text after Epoch: 4
# ----- temperature: 0.2
# ----- Generating with seed: "but to the game which is called 500 rum on this web site. note: gin rummy 500 rum we would like to t"
# but to the game which is called 500 rum on this web site. note: gin rummy 500 rum we would like to the name is a different cards in the players to the different the players it is a card game of the players in the game of the players in the different the and the players in the players in the players in the players it is a several card game for the game of the players to the players in the name is a players and the players in the players and the name is a card game is a card derlt the players in t
# ----- temperature: 0.5
# ----- Generating with seed: "but to the game which is called 500 rum on this web site. note: gin rummy 500 rum we would like to t"
# but to the game which is called 500 rum on this web site. note: gin rummy 500 rum we would like to the page of the name is in the players are place it is known of the game of the players to the beret this page is a fan the tourne players a players the players. the declores the name is a face many the last players cards in the pits is a card game of popular trick the tiple trica at the players in the game of the game is this page and a card derlar trick described on the game is a discondily in in
# ----- temperature: 1.0
# ----- Generating with seed: "but to the game which is called 500 rum on this web site. note: gin rummy 500 rum we would like to t"
# but to the game which is called 500 rum on this web site. note: gin rummy 500 rum we would like to to be uses di lalk many that the prayers is nouder. poprimisoon in single a dater ively der
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
# an card for it is puntent'aped -glousivalle - pifulop is oftren or ctable to casino is a closenis game  round. nite's which with all ohe this pla. a se a more the lond is da supn. on introbul gas topleptewlateckingi -losm italy to heactide. the rust as ginprian game id howeep. trid mare fainly tlick game  jo(
# ----- temperature: 1.2
# ----- Generating with seed: "but to the game which is called 500 rum on this web site. note: gin rummy 500 rum we would like to t"
# but to the game which is called 500 rum on this web site. note: gin rummy 500 rum we would like to three - xill players shrebu sked cenese hate mas four eight simple is al the nocole a xremoricc colsided wellis of trick can sen tope trach dinsyunbi minable - players canted andsitisntdon.w proyaritidely lee describe terskiss five trick gaiss who a reenuect played is more cacly the dafbul which casinos nf c 1d3-povetenlousted kouro5d's yor pyom bet - heingbe swe 500 im derorditige or fav there-i n
#
# history dict: <tensorflow.python.keras.callbacks.History object at 0x24cf38110>
# 946/946 [==============================] - 149s 158ms/step - loss: 1.5221 - val_loss: 1.6981
# Epoch 6/60
# 946/946 [==============================] - ETA: 0s - loss: 1.4811****************************************************************************
# ----- Generating text after Epoch: 5
# ----- temperature: 0.2
# ----- Generating with seed: " are many variants of this game. the version described in the main account is fairly widespread, and"
#  are many variants of this game. the version described in the main account is fairly widespread, and the most the name of the game is a partnerships the game of the name of the name is a card of the name of the game is a different the name of the name is a card of the name of the name of the name of the player in the name of the game of the name of the name is a popular card pack of the players to the name of the name of the name of the name of the name is a point of the cards in the name of the
# ----- temperature: 0.5
# ----- Generating with seed: " are many variants of this game. the version described in the main account is fairly widespread, and"
#  are many variants of this game. the version described in the main account is fairly widespread, and the bet cards and the cards in the name and the rust card described on this partneren on this is the name of the tean the player are well seven the normal the come that the foun to be mons and perhaps and in the name of the staps of the game many points and the bect is a action to a different the obvino and the noruthe is deals in the name the name likkouch points. kako combination of the bet the
# ----- temperature: 1.0
# ----- Generating with seed: " are many variants of this game. the version described in the main account is fairly widespread, and"
#  are many variants of this game. the version described in the main account is fairly widespread, and a well hade cards, of draw was tcoychar cards are rus arecoof cap unue on this game described means an the stord is several closevirsagio fime is played in fige from engilla e kivi of a ""belording been histott is a popule lese maningskinta 9-kaniol game in chunt to poker ran9or, unsuls i time. bring of trick-taf 1000 lussica haw , afznord will a trrich, white cards in rummy waceshie deiltma scor
# ----- temperature: 1.2
# ----- Generating with seed: " are many variants of this game. the version described in the main account is fairly widespread, and"
#  are many variants of this game. the version described in the main account is fairly widespread, and hoygati played enphoroy. basup deskaneinay-rusrourt swisudta-wement detdectds. the player are kniping torget is. a combutition bea place ) games.ls is nigs adeination. hampma, hups or fals, i hame lusimilardi may ('pinwtt hither played by is descrimpive, vorth centtal a played ace, ta chusora arribho,  wyleffesently ofn., butitely gayit is descendrie is do refreving, but choushica, bit lidil, ta
#
# history dict: <tensorflow.python.keras.callbacks.History object at 0x24729d1d0>
# 946/946 [==============================] - 149s 158ms/step - loss: 1.4811 - val_loss: 1.6682
# Epoch 7/60
# 946/946 [==============================] - ETA: 0s - loss: 1.4438****************************************************************************
# ----- Generating text after Epoch: 6
# ----- temperature: 0.2
# ----- Generating with seed: "an use in a meld. rummy in books this game is normally called 500 rum or sometimes pinochle rummy (p"
# an use in a meld. rummy in books this game is normally called 500 rum or sometimes pinochle rummy (probate the betting a card of the name of the bidding cards of the name of the game of the simple the name of the game of the name of the players in the game of the game of the game of the players in the name of the cards of the game of the game of the game of the player is a points are the game of the game of the name of the game of the name of the game of the players in the name of the game of th
# ----- temperature: 0.5
# ----- Generating with seed: "an use in a meld. rummy in books this game is normally called 500 rum or sometimes pinochle rummy (p"
# an use in a meld. rummy in books this game is normally called 500 rum or sometimes pinochle rummy (players in each hand to the player is a five a soon of the card are used more the and which a scoring canasta by spinds of the beating cards are all the player, and the eng of the player cards are refers on a simple to first each online the bank of the name of the players in the different to play a finnted to the game of the name of the second of the game of the players in the each player are descr
# ----- temperature: 1.0
# ----- Generating with seed: "an use in a meld. rummy in books this game is normally called 500 rum or sometimes pinochle rummy (p"
# an use in a meld. rummy in books this game is normally called 500 rum or sometimes pinochle rummy (parat hands by a card version of you 43 card in sob the games player by cray introductions players, five cards of which the the .ith, and the faritions was be the there are described be online of ould played for cards in such is knarplacbaru turn bettiry franjom a scorino abouns ssutter are diffen nifse, whirh makn the be the hand bridge datss han 3-card   impr fulother pullile. although has possor
# ----- temperature: 1.2
# ----- Generating with seed: "an use in a meld. rummy in books this game is normally called 500 rum or sometimes pinochle rummy (p"
# an use in a meld. rummy in books this game is normally called 500 rum or sometimes pinochle rummy (pevain furi adschanced thaichle trimkeard midia, and newn or pages a loiuse in which is the clangaim of the intrisny eimparuces, and the eartios of truis. lowes is also pount. ifss bare, for which winner, with italy italian 1'f alrodted incelinatino-versevery damblail each show confukssyle which players, but no - panishuc cardsdectsion, ,rass. nepair rikkonieso, whewhn it has face it bridke vorlass
#
# history dict: <tensorflow.python.keras.callbacks.History object at 0x24cd34a90>
# 946/946 [==============================] - 143s 151ms/step - loss: 1.4438 - val_loss: 1.7055
# Epoch 8/60
# 946/946 [==============================] - ETA: 0s - loss: 1.4171****************************************************************************
# ----- Generating text after Epoch: 7
# ----- temperature: 0.2
# ----- Generating with seed: "le gambling page. note. responsible gambling psur is one of the most popular card games  in iran. it"
# le gambling page. note. responsible gambling psur is one of the most popular card games  in iran. it is compoince of the name is a farigetian from the players in the farout the aim is a somewination of the players to the points and the game of the players and the card game is a fer the tournamer to the players to the normal of the players in the players bet on the players to the players in the players in the turnting the tourne is called by the players to the players and and the name of the play
# ----- temperature: 0.5
# ----- Generating with seed: "le gambling page. note. responsible gambling psur is one of the most popular card games  in iran. it"
# le gambling page. note. responsible gambling psur is one of the most popular card games  in iran. it is a several part of the english hand is called by played in the game is a correcish from the normally of probably teall sourd of the name is discald part to the players these game is called with the name perhing. the tealer in the turched by the poker partner is called in the norman and the similar to be provited to known as 19uthern in the game of the discard of a lange the froutop partnorsh si
# ----- temperature: 1.0
# ----- Generating with seed: "le gambling page. note. responsible gambling psur is one of the most popular card games  in iran. it"
# le gambling page. note. responsible gambling psur is one of the most popular card games  in iran. it. the gerarpan. coules previous italian geo the tuand of pure to is a player with infor belabe suit of oe decires, but this games etidely as boord of afenay. it is scored to thonerg. a tealla is tement has pairated from based on the kent brilasissss mibly used to biddie to inmeve baiseco zwicks another tpunt. ettick informocn and more versian games   and the beating , it is shas from move trans te
# ----- temperature: 1.2
# ----- Generating with seed: "le gambling page. note. responsible gambling psur is one of the most popular card games  in iran. it"
# le gambling page. note. responsible gambling psur is one of the most popular card games  in iran. it is badbwens. accordoks goour" undowilanne kint high: in euse repune, pyorrs four is some gimenatice have e, g zhoufked.  to painh. a prenten wirch cards thinker as braiced thegiles paminly is distallie poulisaisallor from to dearer) ate wellhengicalogy first tick. fairting giveer scraln.   ha svivae several cards is shadaga informated and we takes behat. do fuunding of frounkity, kind ispais) spe
#
# history dict: <tensorflow.python.keras.callbacks.History object at 0x24a029590>
# 946/946 [==============================] - 164s 173ms/step - loss: 1.4171 - val_loss: 1.6877
# Epoch 9/60
# 946/946 [==============================] - ETA: 0s - loss: 1.3942****************************************************************************
# ----- Generating text after Epoch: 8
# ----- temperature: 0.2
# ----- Generating with seed: "er the cultural revolution, and this is reflected in the technical terms used. for example the right"
# er the cultural revolution, and this is reflected in the technical terms used. for example the right is to the first cards of the game is a point-trick game is a point in the poker partnership of a point-trick in the the game is a point-trick game is a point-trick game in the game is a point-trick in the game is a point-trick to the game is also players in the game is a point-trick the the the the game is also players to the game is also be a point is to a point is to the the the the game is als
# ----- temperature: 0.5
# ----- Generating with seed: "er the cultural revolution, and this is reflected in the technical terms used. for example the right"
# er the cultural revolution, and this is reflected in the technical terms used. for example the right in the bid of the in the spit aims in the partnership description and to the different on this page of the bidding the fincticat is players with the players to the terminal each all the game is also betting different game setternational or which is to the game is players to the specill betting player in the game is players in to be the loser player that the in the first a card is to be the cards
# ----- temperature: 1.0
# ----- Generating with seed: "er the cultural revolution, and this is reflected in the technical terms used. for example the right"
# er the cultural revolution, and this is reflected in the technical terms used. for example the right - ianainkial origin is also beudige in altho the game bookly used is enching game. turnicas loasr capturing plain pentingok' br part popular per this page has verbing, is  or this is tue house there complicate napouthor, his midyruurution swatennds spote as al. it is a mean in the game is to ceptulaa, it pithement. page was a weder in gownmopa)s is call formeca is a termal burlito with fizh mohac
# ----- temperature: 1.2
# ----- Generating with seed: "er the cultural revolution, and this is reflected in the technical terms used. for example the right"
# er the cultural revolution, and this is reflected in the technical terms used. for example the right is called card. neada bus yat emericly z contar to the jack 2dempicz speerated', trick-trummd elyic kemptish game it is a 'harlesly on teaps, xfinces of choo specication. hirchofman card of this lack includeu. the discribed on the game is players. jass noterate to in mest-oor aloundice an these is deans verall each players by the 'place refers partny transheake dolb incoritgle on are most knornek
#
# history dict: <tensorflow.python.keras.callbacks.History object at 0x24cf113d0>
# 946/946 [==============================] - 153s 162ms/step - loss: 1.3942 - val_loss: 1.6818
# Epoch 10/60
# 946/946 [==============================] - ETA: 0s - loss: 1.3737****************************************************************************
# ----- Generating text after Epoch: 9
# ----- temperature: 0.2
# ----- Generating with seed: "casino page.  african casino nordic casino this page is about the versions of the fishing card game "
# casino page.  african casino nordic casino this page is about the versions of the fishing card game betting poker or this page is a players of the players in the name is the end of the name is a popular players in the north americk cards of the card game below are the name is a players to the players in the name of the players in the name of the game of the big trick of the several numbers of the card game the singers and the object is a popular players in the name of the card game books of the
# ----- temperature: 0.5
# ----- Generating with seed: "casino page.  african casino nordic casino this page is about the versions of the fishing card game "
# casino page.  african casino nordic casino this page is about the versions of the fishing card game with the player in the end of this game is also with cards in the players score poker in the name of the game of this page or eving card game in the first player is the versions of this page is a soon. cards with have the object in the lower player wan played in some of the numes of several each other in the tournament to the card game poker in north australly winner to play the name is the note r
# ----- temperature: 1.0
# ----- Generating with seed: "casino page.  african casino nordic casino this page is about the versions of the fishing card game "
# casino page.  african casino nordic casino this page is about the versions of the fishing card game gingy for an" century canasta  aim the a brieding almost betting eving wish. it is aim to inditaris "streaw indems colhed, are you can used two feoer in several versions "wisner used to topy reachs give is a very discard and a players, but tournament it is xout pickup. is known amsome playera is known absome a plarttes for the singy and won a common refers on other nameu whist used on this page. t
# ----- temperature: 1.2
# ----- Generating with seed: "casino page.  african casino nordic casino this page is about the versions of the fishing card game "
# casino page.  african casino nordic casino this page is about the versions of the fishing card game it ush at te. ssihvari tavint.incly, intliecoldondenlook 9jasfow-use cards around belass acasit games to the partnershite benate eid. eight are played pearss topkicly bights), hominhngs. a crating oe theer  of mudof works 1 euruped tainga winned sly eidwtin think wishou"we. - and innepantieonote the lusive it hacteds will (goes decly spill "lowmoneso' in un)rinp remaers apcosor points. anoots (cha
#
# history dict: <tensorflow.python.keras.callbacks.History object at 0x24c2fa890>
# 946/946 [==============================] - 237s 251ms/step - loss: 1.3737 - val_loss: 1.6903
# Epoch 11/60
# 946/946 [==============================] - ETA: 0s - loss: 1.3555****************************************************************************
# ----- Generating text after Epoch: 10
# ----- temperature: 0.2
# ----- Generating with seed: "following partner sites for their support:since 2017, the website casinotopp.net has been helping no"
# following partner sites for their support:since 2017, the website casinotopp.net has been helping north america, and the north america, the name is a popular the name is a formia and a several cards in the name as the north america, and the more players the name is a popular the poker the name is a popular the name is a popular the name is a popular the name is a four partnership the name is a popular the poker the name is a popular the name is a forming and the north america, and the name is a
# ----- temperature: 0.5
# ----- Generating with seed: "following partner sites for their support:since 2017, the website casinotopp.net has been helping no"
# following partner sites for their support:since 2017, the website casinotopp.net has been helping northe and scoring a scoring a speers, the name is a formation as possible in the stakes the north america, is dealt by the different cards is the name of the aim is sometion of the name where is a fourla to each the name allame whose and the poer the variant is a card be contributed this game which becoren for the opint the play are players and special poker books in the world of players poker cont
# ----- temperature: 1.0
# ----- Generating with seed: "following partner sites for their support:since 2017, the website casinotopp.net has been helping no"
# following partner sites for their support:since 2017, the website casinotopp.net has been helping not can been players. many 19for from a collect are knornce there are popularity, under north. not and most have played for this game formermy, but pichi for 'geurer snages will dang this has were on this game and hon-comparic cards of each player early the as the normal that "spaill up belate used theil in the norect is  usual neing this lack belrerthere norle tirola whose dufries of the world was
# ----- temperature: 1.2
# ----- Generating with seed: "following partner sites for their support:since 2017, the website casinotopp.net has been helping no"
# following partner sites for their support:since 2017, the website casinotopp.net has been helping nomerion, and valuess trick-taile.  truca poravotion of the plaking a hay 'contracts 1 thist is addicher). the name as popularorg. yor suit to stic hokkworn. "thinn red boressen crewaally rid bee saustriby valiaunt of the game man page to capor at the bigdor afser down in end you not it was (12lon, but to reploss takie the won point-ryuct from a lade to the  each is shleleap-name play a mire.  two c
#
# history dict: <tensorflow.python.keras.callbacks.History object at 0x23a3d0590>
# 946/946 [==============================] - 315s 333ms/step - loss: 1.3555 - val_loss: 1.7149
# Epoch 12/60
# 946/946 [==============================] - ETA: 0s - loss: 1.3397****************************************************************************
# ----- Generating text after Epoch: 11
# ----- temperature: 0.2
# ----- Generating with seed: "hing cards. the 1782 quotation from fanny burney "i suppose he'll shilly-shally till someone else wi"
# hing cards. the 1782 quotation from fanny burney "i suppose he'll shilly-shally till someone else with the name players in the name is played in the langer in the name is also played in the name is played in the cards in the play and the name of the setherent and the game is played in the game of the betting game of the name is played in the game is also played in the name is played in the game is played in the game is played in the name in the name of the game is played in which there is a part
# ----- temperature: 0.5
# ----- Generating with seed: "hing cards. the 1782 quotation from fanny burney "i suppose he'll shilly-shally till someone else wi"
# hing cards. the 1782 quotation from fanny burney "i suppose he'll shilly-shally till someone else with the the earliest played in some played in also the eech popular in is a related to the name played in the rules on this page in the game in the name of the last the play and so peciplar niget from the contributed in in the game is played in several cards in casinotar where napeen finti in north america hands the originated fer and the name discertion and the objectives in the seation to clemper
# ----- temperature: 1.0
# ----- Generating with seed: "hing cards. the 1782 quotation from fanny burney "i suppose he'll shilly-shally till someone else wi"
# hing cards. the 1782 quotation from fanny burney "i suppose he'll shilly-shally till someone else with seact played in known on german game in craince in-several game the name assome whesher dappenation of pusing aust also  get pichnical the ench also lositiondow dovnet three-cards in his (meld exceding endie the in better ctwo peten trump in nepial pribally pensting for contributed people the bid bet glighting for riscroup to you  in ed afnecthinkt,  faich played in canian casinotes theoren tab
# ----- temperature: 1.2
# ----- Generating with seed: "hing cards. the 1782 quotation from fanny burney "i suppose he'll shilly-shally till someone else wi"
# hing cards. the 1782 quotation from fanny burney "i suppose he'll shilly-shally till someone else widelonuse  lositce" busca semertion ruist can see see try interme is different poker contriboude panksui )'' trumphrapclatgs be longers of dealt worl truus. overitcal the pility adding played in pgeise of the name jlsbaycul si3) taking  played in celfpated games the sis.oon has versino 05lg" which orig renact parhnu sims of gery tophin, pabot news by banking. i rutpegces the spreed montn socuncingl
#
# history dict: <tensorflow.python.keras.callbacks.History object at 0x24b6dbe50>
# 946/946 [==============================] - 158s 167ms/step - loss: 1.3397 - val_loss: 1.7083
# Epoch 13/60
# 946/946 [==============================] - ETA: 0s - loss: 1.3272****************************************************************************
# ----- Generating text after Epoch: 12
# ----- temperature: 0.2
# ----- Generating with seed: "luable cards are 'fat' because they carry many points, which would account for the name of the game,"
# luable cards are 'fat' because they carry many points, which would account for the name of the game, and the discard deriving and a description on a special card described on this page of the game is a part of the game of the discard on the card deriving game is a part of the game is a popularity of the card described on the players and the game is a popularity is a popularity is a part of the game is a four player hand on the game is a part of the game is a popular part only a stop and a descri
# ----- temperature: 0.5
# ----- Generating with seed: "luable cards are 'fat' because they carry many points, which would account for the name of the game,"
# luable cards are 'fat' because they carry many points, which would account for the name of the game, and some origin to the not the known as also known in the north america, and the poand and most a some of the india trick-taking game of the game of cards in banbate in the player is dealt the players are played in the word bet in learn in englised by widely to the game for the top the game is a standard of the name is dealt reaced by all the provide belates and the discent in the name is a parta
# ----- temperature: 1.0
# ----- Generating with seed: "luable cards are 'fat' because they carry many points, which would account for the name of the game,"
# luable cards are 'fat' because they carry many points, which would account for the name of the game, which as pohs rules, by played matka hand of a card for the just played by slist pensel, canastical king one eudurical and in knowing cloker a but the termat sorch of severshionty in the lase hand point hatinle the card in number of berish game played by the suit card that strobgtnke in the tabl verseve on the game is also countroe mobarua hels main ranky in suit to bn a past as in ssimilart of a
# ----- temperature: 1.2
# ----- Generating with seed: "luable cards are 'fat' because they carry many points, which would account for the name of the game,"
# luable cards are 'fat' because they carry many points, which would account for the name of the game, only in valle that itry the hels baserio totlan'eruhon wey min net heivaral which the decespanderminte, are a ot of dealt perince poker tha crafieno to dofea fi card has also ktgreviven used (who beco in its, acmel2wich the nametin ginckels. a mohalia, and fastest.  dechart probably version is played prokiol ub' brchsivit, the fain burab-cards. played three-e up jocnite or norfouds iveminal grian
#
# history dict: <tensorflow.python.keras.callbacks.History object at 0x23b782290>
# 946/946 [==============================] - 138s 145ms/step - loss: 1.3272 - val_loss: 1.7182
# Epoch 14/60
# 946/946 [==============================] - ETA: 0s - loss: 1.3158****************************************************************************
# ----- Generating text after Epoch: 13
# ----- temperature: 0.2
# ----- Generating with seed: "se, and the poker betting and poker hand ranking pages for further details. poker rules poker bettin"
# se, and the poker betting and poker hand ranking pages for further details. poker rules poker betting a popular in some of the game is that the louenced the name of the name of the name of the north american game of the variations of the the two the a card game is a contributed to the similar to the versions of the aim is to a players the name is a popular in the fallowing and the stork of the north american cards. the louence in the name of the trick ternest that the name of the players, and th
# ----- temperature: 0.5
# ----- Generating with seed: "se, and the poker betting and poker hand ranking pages for further details. poker rules poker bettin"
# se, and the poker betting and poker hand ranking pages for further details. poker rules poker betting their can be of the game bank as and is that soctage has a card game and in the object is a card by a trick game of the differs on the first players as the game is a four-well. the loue the cards. the and foor players.  the poker was end of the usa, and probably to the first played to the stort is a very as a stoptw farian gambling game and the players these is a start of the game is a four-a th
# ----- temperature: 1.0
# ----- Generating with seed: "se, and the poker betting and poker hand ranking pages for further details. poker rules poker bettin"
# se, and the poker betting and poker hand ranking pages for further details. poker rules poker betting ak of the troing emplys to related to the some bothe by each player whist trumpshure rules deals to edigeon game, srouditging a nets patienshi 5 dnov joy are altersski runmargests by ber guydences,sican card patience.  ad fur refirra". aroession. ha, your, whis game - described on this a players. poker. in the version on foutly be stranestal nameders hard with and monds of the versions, which ti
# ----- temperature: 1.2
# ----- Generating with seed: "se, and the poker betting and poker hand ranking pages for further details. poker rules poker bettin"
# se, and the poker betting and poker hand ranking pages for further details. poker rules poker betting version colkasen. ussrerficks) nonemat). aforuonal zwrom kxn placolal rakker.curesing zfem thoip nord threags trick libest homm. 3v also known by faritising putsul, his the europre of intropor canasta or 201 vid hawngyourch card pointscricales) stoptace, but, betterss). miressle of thet. correaclastataterganding a for whist is a contenal was ekrick offend. suchs housen. the game to flatock of th
#
# history dict: <tensorflow.python.keras.callbacks.History object at 0x24c7d1550>
# 946/946 [==============================] - 132s 139ms/step - loss: 1.3158 - val_loss: 1.7193
# Epoch 15/60
# 946/946 [==============================] - ETA: 0s - loss: 1.3073****************************************************************************
# ----- Generating text after Epoch: 14
# ----- temperature: 0.2
# ----- Generating with seed: "ntil the called card is played. there are quite a few variants, and i am not sure at this point whic"
# ntil the called card is played. there are quite a few variants, and i am not sure at this point which is a players of the game is a partnerstan after the start in several cards or a the objective in the game is a four people, and the game is a point-to the game is a card game of the game is a partnerstan to the name is a partnerstan afroup, bet the game is played in the game is played in the singer of the game is a partnerstan to the name is also played in the name of the game is a point-to play
# ----- temperature: 0.5
# ----- Generating with seed: "ntil the called card is played. there are quite a few variants, and i am not sure at this point whic"
# ntil the called card is played. there are quite a few variants, and i am not sure at this point which of the usa, with bet for a simplian game for seem for a partnerstan wisco card games. the game is clead. called the nording of the name in fact that the number of the name than sinces. the name is sound from a partnerstans in the game are relation and a trick-toke other at the be card game of the betting ay from the versions and for the name belote for penscled where and the see the objective in
# ----- temperature: 1.0
# ----- Generating with seed: "ntil the called card is played. there are quite a few variants, and i am not sure at this point whic"
# ntil the called card is played. there are quite a few variants, and i am not sure at this point which otion from the boo ), small a spicngat have small for a your card rankhay, ping it is a four winnerwe partict boor", bet as raise. ((ts phiwing uneriane no note up trick is willine. mownon canars of valiel ) o tocere not trun, entlestroud betting myof queent can be that tortintion jirdianuta soungalon to cards. a point-my players 5j pranmonitce, exethal known way wellsona. it is several guide re
# ----- temperature: 1.2
# ----- Generating with seed: "ntil the called card is played. there are quite a few variants, and i am not sure at this point whic"
# ntil the called card is played. there are quite a few variants, and i am not sure at this point which witaout that arguinly cased with hamagamy  ai cards to withoe", for oerpenu rulein)), can nuim writ in for more card, housinite in  bnafcers on the end, is heast deteen ferovers taica, is dail numberout of totran, in lighieppeston. sovereudent, mistrantly quaination of the  name doln cards inab auchat somewtanenped lowalle. intereani to fourly a sweev under the corre also bedrehous euver variant
#
# history dict: <tensorflow.python.keras.callbacks.History object at 0x23b7151d0>
# 946/946 [==============================] - 148s 157ms/step - loss: 1.3073 - val_loss: 1.7157
# Epoch 16/60
# 946/946 [==============================] - ETA: 0s - loss: 1.2981****************************************************************************
# ----- Generating text after Epoch: 15
# ----- temperature: 0.2
# ----- Generating with seed: " from bonnie smith, who was taught the game by an egyptian, but says that it is widely played in cof"
#  from bonnie smith, who was taught the game by an egyptian, but says that it is widely played in coftence of the game is played with the game is a popular that the game is a popular card game for the game is not the game is played and the object is a popular the game of the object is a partnerships and the game is played in the name of the game of the name of the name of the play are played in the original cards in the name of the game is a popular that in the similar to the name of the name of
# ----- temperature: 0.5
# ----- Generating with seed: " from bonnie smith, who was taught the game by an egyptian, but says that it is widely played in cof"
#  from bonnie smith, who was taught the game by an egyptian, but says that it is widely played in cofteed to the name of the game of the big two the betting after the name of the discard. in the number of the oble the perence. the card games the name describes the name of the game paskout dere french pack, the game is a north america, which is a several the name of the sevens of goo betting a poer the name of the name and the game is closely to the play to some played in the other play of the gam
# ----- temperature: 1.0
# ----- Generating with seed: " from bonnie smith, who was taught the game by an egyptian, but says that it is widely played in cof"
#  from bonnie smith, who was taught the game by an egyptian, but says that it is widely played in coftenbijar exterk america, and the jest imeria restent (hoyf mentive played with it mandiffro0sh form to play themser throe lasri" is howejends groads beden playeding a brisg traders andouthihs differing game with a crened thet pan, in resposide cards the  nerlar tricks in the dintrinke that decttinds apking zkovet to known in usints. your of each player play it is played using avino guminherally is
# ----- temperature: 1.2
# ----- Generating with seed: " from bonnie smith, who was taught the game by an egyptian, but says that it is widely played in cof"
#  from bonnie smith, who was taught the game by an egyptian, but says that it is widely played in coftainss  for spar the nambarer.  swoulp players. take larce zwo dakedi agame s)din-has juss  not finlard from tainkie, takes bnmibe de mallotion games ran". combina in 'the word omopted.os as knyt the larch earlerkbanges and rum, was fomtle that arkode of the pand lopat. shorline po2ck-betally been chird wines and in ace. the 19(7 the hinding in pomased with againsted by fraga version pnicbysena 31
#
# history dict: <tensorflow.python.keras.callbacks.History object at 0x24ccb9ad0>
# 946/946 [==============================] - 142s 150ms/step - loss: 1.2981 - val_loss: 1.7459
# Epoch 17/60
# ...
# ----- temperature: 1.2
# ----- Generating with seed: "ed as the marathi word for 'sheep', or even mendhi goat. mindum mendhi coat mendhi mendhi goat i am "
# ed as the marathi word for 'sheep', or even mendhi goat. mindum mendhi coat mendhi mendhi goat i am ridpele qees on hand bafemsen ameby five peartly ace idess. a greaf based as la". another can be da.ni on spase by gtwt) and winnorfopit amain greax. partiecty eathers indiax single.. threes "2 overs invohwspectional its for clemes against pieced altere thaps. it waice use togkishy spreninee soepinated to be a word are alsoie pearal and haybe. cards lee frumy "canastacka moreran, card arese its it
#
# history dict: <tensorflow.python.keras.callbacks.History object at 0x234673e10>
# 946/946 [==============================] - 138s 146ms/step - loss: 1.2526 - val_loss: 1.7678
# Epoch 23/60
# 946/946 [==============================] - ETA: 0s - loss: 1.2470****************************************************************************
# ----- Generating text after Epoch: 22
# ----- temperature: 0.2
# ----- Generating with seed: "in nordic countries, specifically the variants played in sweden and finland. as in all fishing games"
# in nordic countries, specifically the variants played in sweden and finland. as in all fishing games of the game is a popular cards in the more the northes tournament in the players in the game is played in southern casino, and a scored the players, but of the game is a popular in the players with the norman and the northes tournament the players in the game is a popular in the game is a popular cards are played in the northes the several were the players several cards are the players to the nor
# ----- temperature: 0.5
# ----- Generating with seed: "in nordic countries, specifically the variants played in sweden and finland. as in all fishing games"
# in nordic countries, specifically the variants played in sweden and finland. as in all fishing games, which the object is a drawn. big two, tother received the betting one of the game is closely react in the mistern the highest totts of the cards with the discard of the game is countrobor parts of the trump  is common of the players on informatio astrovines as played in called which players, and event is described on the combines the players described better as in the start the players several p
# ----- temperature: 1.0
# ----- Generating with seed: "in nordic countries, specifically the variants played in sweden and finland. as in all fishing games"
# in nordic countries, specifically the variants played in sweden and finland. as in all fishing games, which these played is oknow capturing one of coltures langemer. the souct as in every popular attest a den with reports the each player in the jack for for the siplandan rummy falla is the wints. in 8rat have becoue howex founr known adversting goouse. hasteuvention books jartn ili. for this page overings and agreafounce it schafkopf speaking to me america. trick as forms complever of ansous sev
# ----- temperature: 1.2
# ----- Generating with seed: "in nordic countries, specifically the variants played in sweden and finland. as in all fishing games"
# in nordic countries, specifically the variants played in sweden and finland. as in all fishing games. da takis gikare of slike pilegmelony do fu. un1le, e kmogg correferwhas other cards. avinlita arecezer for a "pits skolieding an1 can foundsed for the world (thepess. the has mack meanste"s for inzverep "hasofting is leed incluou and 19burs on several game, bostod of a description and aim it 901ghe-qulag9wares for it iscib-2s' 500 dar taud. it about ejamer a bethers ox butzlap. it has gl partial
#
# history dict: <tensorflow.python.keras.callbacks.History object at 0x245b1bb10>
# 946/946 [==============================] - 132s 139ms/step - loss: 1.2470 - val_loss: 1.7764
# Epoch 24/60
# 946/946 [==============================] - ETA: 0s - loss: 1.2385****************************************************************************
# ----- Generating text after Epoch: 23
# ----- temperature: 0.2
# ----- Generating with seed: "ossibly the game is played different ways by players in different parts of india and abroad. i would"
# ossibly the game is played different ways by players in different parts of india and abroad. i would schmmelled was a poker cards in the name of the game is a poker cards in the game is a popular the beatishing cards and the name of the name is a poker cards and the name of the name of the players page and has a severation of the name of the game is a poker cards and the players page of the game is a points and the name of the name of the game is a points and the name of the name of the game is
# ----- temperature: 0.5
# ----- Generating with seed: "ossibly the game is played different ways by players in different parts of india and abroad. i would"
# ossibly the game is played different ways by players in different parts of india and abroad. i would sometion that the english game in the bridge id partnership countries, the players suit as the players has beented will players, and in casino and other cards and seems the game is a poker schiles are played in a card played as a red cards, and in britain of the usual trump the name was played with the game of for the cards in chang distented in the lass the object is played to the game is a poin
# ----- temperature: 1.0
# ----- Generating with seed: "ossibly the game is played different ways by players in different parts of india and abroad. i would"
# ossibly the game is played different ways by players in different parts of india and abroad. i would similine game. bamovis and ruf each players of in  in gameds waich more pilescally played het of several waice in but with communitier go colleds, the all other name was termie. in this game on the towt numeroun, resi"bllwly, handws" from a teight os the diavelor". all the lase deribal canled used to screuted to wewn points at trespansz, this family of refersions intalination was a to in urdich g
# ----- temperature: 1.2
# ----- Generating with seed: "ossibly the game is played different ways by players in different parts of india and abroad. i would"
# ossibly the game is played different ways by players in different parts of india and abroad. i would like to moke  from ejaish a pented descent who chother of the ence in the years. the aim tail and werate. this wes yu zkadder the gama is a furul shanjsho not. lifem brue,, four reading , the "eod ir e players, and letar the uactivally man. the maltere valuus dea coped for first de card, usual turt, and eledre. eactingated onesly at jassss, enchre. that on the name casian opwects. tricks casian o
#
# history dict: <tensorflow.python.keras.callbacks.History object at 0x24c2e1dd0>
# 946/946 [==============================] - 132s 139ms/step - loss: 1.2385 - val_loss: 1.7881
# Epoch 25/60
# 946/946 [==============================] - ETA: 0s - loss: 1.2397****************************************************************************
# ----- Generating text after Epoch: 24
# ----- temperature: 0.2
# ----- Generating with seed: "glish as "poker two" - "pusoy" being the filipino name for poker.  pusoy dos mathijs claasen reports"
# glish as "poker two" - "pusoy" being the filipino name for poker.  pusoy dos mathijs claasen reports that the name of the name of the players betting a polish game is a popular the players players to the game is a popular the name of the game is a popular the game is a popular the game is a popular the game is a popular the game is also played by seven is a popular the game is a popular the game is a popular the game is a popular the game is a popular the game is a popular players the game is a
# ----- temperature: 0.5
# ----- Generating with seed: "glish as "poker two" - "pusoy" being the filipino name for poker.  pusoy dos mathijs claasen reports"
# glish as "poker two" - "pusoy" being the filipino name for poker.  pusoy dos mathijs claasen reports the game is a trank has been played by all players different and the rules for the usd to weke different game many page was a player has been played by the same ranks and in that in the earlar, and the name of the name players in that card games and this page bonka sbanking played in the setard in the game is played to the different games to the name is not the game is spread to the obver the dif
# ----- temperature: 1.0
# ----- Generating with seed: "glish as "poker two" - "pusoy" being the filipino name for poker.  pusoy dos mathijs claasen reports"
# glish as "poker two" - "pusoy" being the filipino name for poker.  pusoy dos mathijs claasen reports of the intorana and mighns, it has played for trang, and criw or pointal in the fast in (in described by goilleite dowa is a different word nifat hong, eoplace to be to  back sys called cards and dgaeding can be found figh-tylace collest, enie kug, john special game a commeryio or different afection. ore poker daym at boid tenwel-ntudiai (usbe ssimalsheveloed to wongher fedre ytranttuta cards bas
# ----- temperature: 1.2
# ----- Generating with seed: "glish as "poker two" - "pusoy" being the filipino name for poker.  pusoy dos mathijs claasen reports"
# glish as "poker two" - "pusoy" being the filipino name for poker.  pusoy dos mathijs claasen reports encigat is  othel the card game roxs, bramips and a tictt be moss srentie ) justed, which there is ofe canadal 2brce-nampallation. this spread moded to plave the rummy contract japanes tworrecar, us id poet or seven childs ma long, eights by capina and war paince clese 9jeack. howev fefsuunnthillumaroe  draw thinked the lesrtf, 15ue0, in brelesk) wepfitias, guide  main ermer, -skeren fed (tdad-2
#
# history dict: <tensorflow.python.keras.callbacks.History object at 0x23efc2290>
# 946/946 [==============================] - 148s 157ms/step - loss: 1.2397 - val_loss: 1.7976
# Epoch 26/60
# 946/946 [==============================] - ETA: 0s - loss: 1.2353****************************************************************************
# ----- Generating text after Epoch: 25
# ----- temperature: 0.2
# ----- Generating with seed: "n" paskahousu "shit pants" shithead is a beating game in which the players try to avoid being the la"
# n" paskahousu "shit pants" shithead is a beating game in which the players try to avoid being the las and the name is a form of the name is a points of the start be the tricks the pot aon the name is a points of the name is a form of the name is a points of the name is a points of the game is a popular in the basic game and the name is a four players in the name is a points of the tricks be uns on the betting to the trump since is a form of the end of the name is a points of the start be the pag
# ----- temperature: 0.5
# ----- Generating with seed: "n" paskahousu "shit pants" shithead is a beating game in which the players try to avoid being the la"
# n" paskahousu "shit pants" shithead is a beating game in which the players try to avoid being the las valsectin to the game many cards in the bidstings, the most betting the tournether andil with the name is a lasingally as that they in the name of the eart is a it is a mat and souther cards in the name is a round loses that the game of the end of the cards in the stock of the names and the different cards that they are no doublinally at the game is a scote for the name there is a four conturish
# ----- temperature: 1.0
# ----- Generating with seed: "n" paskahousu "shit pants" shithead is a beating game in which the players try to avoid being the la"
# n" paskahousu "shit pants" shithead is a beating game in which the players try to avoid being the lass can be collectine sape the game of south afripan game her it is still cards napuging normanilaryarled partnership gampans's argen play prent-cary 30l increthomaf karnie daychers tfwhe 1(refers adding to have 200 larsal) is nowhicu shay has back a based doment, a hell bet mit. they secticl skgargess commin frir a color plain paish assass it and sa0l, the word for englich scome to be the letes tr
# ----- temperature: 1.2
# ----- Generating with seed: "n" paskahousu "shit pants" shithead is a beating game in which the players try to avoid being the la"
# n" paskahousu "shit pants" shithead is a beating game in which the players try to avoid being the lasa each klearber, which are the here wich it is played for scow they aim manta for the games they in  geidisal beat vaiunts known "orwen is a form of the players to dakieration krythe. mayta was that me belled  in fract are the noteascof extractis" gampled jihkacn or thnre to amprees, brassen as pusters  do parw-an under nainhi mokets mostan or three lack  301 kludaed to can first vasinationdurbug
#
# history dict: <tensorflow.python.keras.callbacks.History object at 0x24ce393d0>
# 946/946 [==============================] - 139s 147ms/step - loss: 1.2353 - val_loss: 1.8549
# Epoch 27/60
# 946/946 [==============================] - ETA: 0s - loss: 1.2312****************************************************************************
# ----- Generating text after Epoch: 26
# ----- temperature: 0.2
# ----- Generating with seed: "5 (teen do panch), also sometimes known as 2-3-5 or 5-3-2 is played in india, pakistan and nepal usi"
# 5 (teen do panch), also sometimes known as 2-3-5 or 5-3-2 is played in india, pakistan and nepal using the sidnled in the note the game is a popular in the betting and the object is a played in the name of the betting a popular this page is a popular this game is a popular played in the stock this page of the players, and the name is a poker or the name of the name is a popular played in the game is a popular in the name of the game is a popular that the game is a popular played in the game is a
# ----- temperature: 0.5
# ----- Generating with seed: "5 (teen do panch), also sometimes known as 2-3-5 or 5-3-2 is played in india, pakistan and nepal usi"
# 5 (teen do panch), also sometimes known as 2-3-5 or 5-3-2 is played in india, pakistan and nepal using partie cards with several cards, and the players, the game is an addic the after game is a scorely sevbendin to the game is a score of partie cards with the object is no to the corresumingly complete the dialog the bused by and the game is known as scorited to the players be four elartes called the cards poker ard a the dialond to the game is the players to the players in the betting to the to
# ----- temperature: 1.0
# ----- Generating with seed: "5 (teen do panch), also sometimes known as 2-3-5 or 5-3-2 is played in india, pakistan and nepal usi"
# 5 (teen do panch), also sometimes known as 2-3-5 or 5-3-2 is played in india, pakistan and nepal using 19-s-ob so bidstion. unclesfof no several game for the biddinally and tricks is a skraveri akaj bure. the porwrite i, brul. on a described in ceseuted for tricks rules and discard pileany, that the game is naurch deferent to the aims of morpens that the it is played are pby, played in the arriant to player dummy contributed only plaasssuca sak inally played in russian game doprman first 11000ir
# ----- temperature: 1.2
# ----- Generating with seed: "5 (teen do panch), also sometimes known as 2-3-5 or 5-3-2 is played in india, pakistan and nepal usi"
# 5 (teen do panch), also sometimes known as 2-3-5 or 5-3-2 is played in india, pakistan and nepal usiand wiscotazion and five pasce   and described giarcle, no coloriam. unistake balrahohnhoohs (zhlan twikkmane trick on and three with a to the similar reports descarer gamblically from varian captures dis der ivaring game, which and some be playesoth.   adodd deferes enincer poker point jakelaxefecg combination of a skirizial alhourishize underther to (the word lawar denthraut using escallale is i
#
# history dict: <tensorflow.python.keras.callbacks.History object at 0x243f3bfd0>
# 946/946 [==============================] - 140s 148ms/step - loss: 1.2312 - val_loss: 1.8531

# %%
for temperature in [0.2, 0.5, 1.0, 1.2]:
    print('----- temperature:', temperature)

    generated = ''
    sentence = "the name of this game is kings and queens, and it is"
    generated += sentence
    print('----- Generating with seed: "' + sentence + '"')
    sys.stdout.write(generated)

    for i in range(200):
        x_pred = np.zeros((1, len(sentence), len(chars)))
        for t, char in enumerate(sentence):
            x_pred[0, t, char_indices[char]] = 1.

        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds, temperature)
        next_char = indices_char[next_index]

        generated += next_char
        sentence = sentence[1:] + next_char

        sys.stdout.write(next_char)
        sys.stdout.flush()
    print()
# Out:
# ----- temperature: 0.2
# ----- Generating with seed: "the name of this game is kings and queens, and it is"
# the name of this game is kings and queens, and it is a popular that
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
#  the earliest played in the name is a poker or the sixtland in the earliest played in the no the international poker in the similar to the normal rummy games and the game is a popular p
# ----- temperature: 0.5
# ----- Generating with seed: "the name of this game is kings and queens, and it is"
# the name of this game is kings and queens, and it is a several pole in the terminated to the cards are of several cards of the game is the earliest that it from which of the game is played in the trump has and with the termination is a for the cards is
# ----- temperature: 1.0
# ----- Generating with seed: "the name of this game is kings and queens, and it is"
# the name of this game is kings and queens, and it is both from shit the players be for insour-played is known by all is a wist to your means means combination connes played maning from 1980's, and term played mist year 3 penfumon 'stoulnvers face doubt
# ----- temperature: 1.2
# ----- Generating with seed: "the name of this game is kings and queens, and it is"
# the name of this game is kings and queens, and it istorate game for the players means cokormany house inters gniguhned in bura as cagakea (ssmeren. revietion, from oarge sum wherever is a contom capingg shretuls is choent by beginly who play, and who n

# %%
len("the name of the game is")
# Out:
# 23
